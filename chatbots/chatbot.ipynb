# %%
import os
from dotenv import load_dotenv
from IPython.display import Markdown, display
from openai import OpenAI

# %%
load_dotenv(override=True)
api_key = os.getenv('OPENAI_API_KEY')

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
elif api_key.strip() != api_key:
    print("An API key was found, but it looks like it might have space or tab characters at the start or end - please remove them - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")

# %%
BASE_URL = "http://localhost:11434/v1"
API_KEY = "ollama"
MODEL = "llama3.2"
# MODEL = "gpt-5-nano"
# MODEL = "deepseek-r1:1.5b"

# SYSTEM_PROMPT = (
#     "You are a helpless assistant that doesn't know anything. "
#     "You make up answers as you go along. "
#     "You answer with absolute confidence and a serious tone, but most of the information you provide is wrong or made up. "
#     "Reply in markdown."
# )
SYSTEM_PROMPT = (
    "You are a basic assistant. "
    "You solve simple tasks. "
    "Your answers are serious and straight to the point. "
    "Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown."
)

USER_PROMPT = input("Enter your prompt: ")
# THINKING_PROMPT = "First describe your thought process then give the answer"

messages = [
    {"role": "system", "content": SYSTEM_PROMPT},
    {"role": "user", "content": USER_PROMPT}
]

# %%
my_ai = OpenAI(base_url=BASE_URL, api_key=API_KEY)
# my_ai = OpenAI()

# %%
print("Answering...")

response = my_ai.chat.completions.create(model=MODEL, messages=messages)

print("done")
# Out:
# Answering...
# done

# %%
answer = response.choices[0].message.content
print("Q:", USER_PROMPT)
display(Markdown(answer))
# Out:
# Q: Toss 2 coins; one is heads - what’s the chance the other is tails? First describe your thought process then give the answer
# To solve this problem, I'll consider the possible outcomes when tossing two coins.
#
# When tossing two coins, there are four possible outcomes:
# - Both heads (HH)
# - Both tails (TT)
# - Heads followed by tails (HT)
# - Tails followed by heads (TH)
#
# Out of these outcomes, two result in a tail for at least one coin. In the case of the first coin being heads and the second one being tails. So the probability would be
# Probability = Number of desired outcomes / Total number of possible outcomes.
#
# Number of desired outcomes = 2
# Total number of possible outcomes = 4
#
# Probability = 2/4
#
# Probability = 1/2
